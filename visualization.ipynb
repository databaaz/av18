# %%
# %matplotlib inline
import importlib
import matplotlib.pyplot as plt
import numpy as np
from data import *

# %% [markdown]
# # Basic Plot

# %%
x=[1,2,3,4]
y=[1,4,9,16]
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(x,y,'ro')
plt.subplot(2,2,3)
plt.plot(x,y,'g--')
plt.subplot(2,2,4)
plt.plot(x,y,'bs')
plt.show()

# %% [markdown]
# ```python
# The following format string characters are accepted to control
# the line style or marker:
#
# ================    ===============================
# character           description
# ================    ===============================
# ``'-'``             solid line style
# ``'--'``            dashed line style
# ``'-.'``            dash-dot line style
# ``':'``             dotted line style
# ``'.'``             point marker
# ``','``             pixel marker
# ``'o'``             circle marker
# ``'v'``             triangle_down marker
# ``'^'``             triangle_up marker
# ``'<'``             triangle_left marker
# ``'>'``             triangle_right marker
# ``'1'``             tri_down marker
# ``'2'``             tri_up marker
# ``'3'``             tri_left marker
# ``'4'``             tri_right marker
# ``'s'``             square marker
# ``'p'``             pentagon marker
# ``'*'``             star marker
# ``'h'``             hexagon1 marker
# ``'H'``             hexagon2 marker
# ``'+'``             plus marker
# ``'x'``             x marker
# ``'D'``             diamond marker
# ``'d'``             thin_diamond marker
# ``'|'``             vline marker
# ``'_'``             hline marker
# ================    ===============================
#
#
# The following color abbreviations are supported:
#
# ==========  ========
# character   color
# ==========  ========
# 'b'         blue
# 'g'         green
# 'r'         red
# 'c'         cyan
# 'm'         magenta
# 'y'         yellow
# 'k'         black
# 'w'         white
# ==========  ========
# ```

# %% [markdown]
# ## Note
# 1. Line plot is helpful if we have time scale along horizontal axis.
# 2. In many other cases, to assess correlation between 2 variables, **scatter plot** is a better choice

# %% [markdown]
# # Scatter plot

# %%
plt.scatter(x,y, color='magenta')
plt.show()

# %% [markdown]
# ## Additional attributes
# - **s (size)**: size  of each marker. list
# - **c (colors)**: colors of the markers. color

# %% [markdown]
# # Basic Customizations

# %%
plt.plot(year, physical_sciences, color='blue')
plt.plot(year, computer_science, color='red')

plt.xlabel('Year')
plt.ylabel('% of Women')
# plt.yticks([0,10,20,30,40,50,55,60], ['0', '10%', '20%', '30%', '40%', '50%', '55%', '60%'])
plt.title('% of women graduates in Physical Science and Computer Science')
plt.show()

# %% [markdown]
# ## 1. Multiple plots in 1 figure

# %% [markdown]
# ### plt.axes([xlo, ylo, width, height]) - different plots on distinct axes
# xlo, ylo, width, height - all in range 0, 1 i.e proprotion of figure size
# ### plt.subplot(m,n,k) - no need to specify axis dimension for distinct plots

# %%
plt.axes([0.05, 0.05, 0.425, 0.9])
plt.plot(year, physical_sciences, color='blue')
plt.axes([0.525, 0.05, 0.425, 0.9])
plt.plot(year, computer_science, color='red')
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot(year, physical_sciences, color='blue')
plt.title('Physical Sciences')

plt.subplot(2,2,2)
plt.plot(year, computer_science, color='red')
plt.title('Computer Science')

plt.subplot(2,2,3)
plt.plot(year, health, color='yellow')
plt.title('Health Professions')

plt.subplot(2,2,4)
plt.plot(year, education, color='green')
plt.title('Education')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Specifying Axis limits, Legends

# %% [markdown]
# ### plt.axis((xmin,xmax,ymin,ymax)) - specify limits of axes to be shown
# Necessary when we want to zoom in, expand the plot and see a portion of plot or set axis range to include important points (like origin)
# ##### set limits for axis individually:
# plt.xlim([xmin,xmax])
# plt.ylim((ymin,ymax))

# %%
plt.plot(year, computer_science, color='red')
plt.plot(year, physical_sciences, color='blue')
plt.axis([1990,2010,0,50])
plt.xlim()
plt.show()

# %% [markdown]
# ### plt.legend(loc="top right")
# To distinctly identify different plots using labels
# ```python
# Location String   Location Code
# ===============   =============
# 'best'            0
# 'upper right'     1
# 'upper left'      2
# 'lower left'      3
# 'lower right'     4
# 'right'           5
# 'center left'     6
# 'center right'    7
# 'lower center'    8
# 'upper center'    9
# 'center'          10
# ```

# %%
plt.plot(year, physical_sciences, color="blue", label="Physical Sciences")
plt.plot(year, computer_science, color="red", label="Computer Science")
plt.legend(loc='upper left')

plt.xlabel('Year')
plt.ylabel('Enrolment(%)')
plt.title('Undergraduate enrolment of women')

plt.show()

# %% [markdown]
# ## 3. Annotations in Plots

# %% [markdown]
# ### plt.annotate(s,xy,xytext, arrowprops)
# To annotate a point in graph using arrow and text

# %%
plt.plot(year, health, color='yellow', label="Health Professions")
plt.plot(year, education, color='green', label="Education")
plt.legend(loc='lower right')
#plt.grid(True)

xmax = year[np.argmax(health)]
ymax = np.max(health)
plt.annotate(s="Inflection", xy=[xmax,ymax], xytext=[xmax+5,ymax-5],arrowprops={"facecolor":"black"})
plt.show()

# %% [markdown]
# ## 4. Using Styles

# %% [markdown]
# ### plt.style - Modifying Style

# %%
plt.style.use('seaborn') #ggplot

plt.subplot(2,2,1)
plt.plot(year, physical_sciences, color='blue')
plt.title('Physical Sciences')

plt.subplot(2,2,2)
plt.plot(year, computer_science, color='red')
plt.title('Computer Science')

plt.subplot(2,2,3)
plt.plot(year, health, color='yellow')
plt.title('Health Professions')

plt.subplot(2,2,4)
plt.plot(year, education, color='green')
plt.title('Education')

plt.tight_layout()
plt.show()

# %%
print(plt.style.available)
# Out:
# ['_classic_test', 'bmh', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-white', 'seaborn-colorblind', 'Solarize_Light2', 'ggplot', 'seaborn-bright', 'fast', 'grayscale', 'seaborn-whitegrid', 'seaborn-muted', 'seaborn-pastel', 'seaborn-dark', 'seaborn', 'dark_background', 'classic', 'seaborn-dark-palette', 'seaborn-deep', 'seaborn-notebook', 'seaborn-darkgrid', 'seaborn-poster', 'seaborn-talk', 'seaborn-paper']

# %%
import numpy as np
x = np.linspace(-2,2,3)
y = np.linspace(-1,1,5)
x,y
# Out:
# (array([-2.,  0.,  2.]), array([-1. , -0.5,  0. ,  0.5,  1. ]))

# %%
a,b=np.meshgrid(x,y)

# %%
a,b
# Out:
# (array([[-2.,  0.,  2.],
#         [-2.,  0.,  2.],
#         [-2.,  0.,  2.],
#         [-2.,  0.,  2.],
#         [-2.,  0.,  2.]]), array([[-1. , -1. , -1. ],
#         [-0.5, -0.5, -0.5],
#         [ 0. ,  0. ,  0. ],
#         [ 0.5,  0.5,  0.5],
#         [ 1. ,  1. ,  1. ]]))

# %% [markdown]
# # 2D Arrays

# %% [markdown]
# ## MeshGrid
# 1. Used for visualizing bivariate functions

# %% [markdown]
# ### meshgrid(u,v)
# - Replicates 1-D arrays u and v along different axes to generate 2-D arrays - X, Y.
# - X & Y represent the co-ordinates of generated grid.
# - Resulting arrays X and Y have identical shapes.
# - Their entries taken pairwise represent co-ordinates of a rectangular grid.

# %% [markdown]
# ## 1. Visualizing bivariate distributions
# Inferring distributions from data - fundamental problem in data analysis

# %% [markdown]
# ### Histograms in 1D
# - Choose bins(intervals)
# - Too few bins will **oversimplify reality** - won't show you the details.
# - Too many bins will **overcomplicate reality** and won't show the bigger picture.
# - Count realizations within bins, and then plot
# - Straight line segments are the only possible shape for bins in 1D
# **counts, bins, patches = plt.hist(x, bins=25)**

# %%
x= np.random.randint(10, 50, (40,1))

# %%
plt.style.use('bmh')
plt.hist(x,10, range=(10,50))
# Out:
# (array([6., 6., 3., 4., 5., 2., 4., 3., 1., 6.]),
#  array([10., 14., 18., 22., 26., 30., 34., 38., 42., 46., 50.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### hist2d() - Rectangular Binning
# **plt.hist2d(x, y, bins=(nx, ny), range=((xmin, xmax), (ymin, ymax))**
# - nx, ny - the number of bins to use in the horizontal and vertical directions
# - range(optional) - rectangular region in which the samples are counted in constructing the 2D histogram
#   * xmin, xmax - lower and upper limits for the variables on the x-axis
#   * ymin, ymax - lower and upper limits for the variables on the y-axis

# %%
# Generate a 2-D histogram
plt.hist2d(hp, mpg, bins=(20,20), range=[(40,235), (8,48)])

# Add a color bar to the histogram
plt.colorbar()

# Add labels, title, and display the plot
plt.xlabel('Horse power [hp]')
plt.ylabel('Miles per gallon [mpg]')
plt.title('hist2d() plot')
plt.show()

# %% [markdown]
# ### hexbin() - Hexagonal Binning
# - Hexagons may not be regular because of different scalings on the two axes

# %% [markdown]
# ## 2. Visualizing bivariate functions
# - Data arising from a bivariate function can be sampled using 2d-array

# %% [markdown]
# ### Pseudocolor Plot - pcolor()
#  * Blocky/pixelated
#  * Appropriate for data that is inherently continuous

# %%
u = np.linspace(-2,2,63)
v = np.linspace(-1,1,33)

X,Y = np.meshgrid(u,v)
Z = X**2/25 + Y**2/4 # should represent grayscale pixels, high values = lighter colors, low=darker

plt.pcolor(Z, cmap='autumn')
plt.axis('tight') #to clip any extra whitespace
plt.show()

# %% [markdown]
# - Observations
#     * Plot has many different colored pixels instead of grayscale pixels.
#     * The plot has large integer values(determined by matrix dimensions) as x and y ticks instead of actual co-ordinates used to compute the matrix
# - colormap: A color line that maps numeric values to colors in some continuous way. The set of colors used in the plot is determined by a colormap which smoothly maps values to colors

# %%
plt.pcolor(Z, cmap='viridis') #'summer', 'autumn', 'winter' and 'spring'; 'coolwarm', 'magma', 'viridis', 'jet'(D); 'Greens', 'Blues', 'Reds', and 'Purples'
plt.colorbar()
plt.show()

# %% [markdown]
# ###  Plot using meshgrid matrices

# %%
plt.pcolor(X,Y,Z, cmap='gray') #Axes determined by meshgrid arrays X & Y
plt.show()

# %% [markdown]
# ### Contour Plots
#  - For data that varies continuously
#  - Visualizing data without displaying all the available sample values, unlike pcolor that displays entire array
#  - Smooth curves along which the function represented by the the data has a constant value

# %%
plt.contour(Z,30, cmap='viridis')
plt.show()

# %%
#Filled Contour Plots
plt.contourf(X,Y,Z,30)
plt.show()
